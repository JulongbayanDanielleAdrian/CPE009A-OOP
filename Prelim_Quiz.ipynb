# %% [markdown]
# <a href="https://colab.research.google.com/github/qdaajulongbayan01/CPE009A-OOP/blob/main/Prelim_Quiz.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ***Prelim Quiz***

# %%
n=20
totalnumbers=n
sum=0
average=0
while n>=0:
  sum+=n
  n-=1
print("The sum is: " +str(sum))
average=sum/totalnumbers
print("The average is: " +str(average))
# Out:
# The sum is: 210
# The average is: 10.5

# %% [markdown]
# # ***Flowchart***

# %% [markdown]
# ![Prelim Quiz.png](data:image/png;base64,...)
